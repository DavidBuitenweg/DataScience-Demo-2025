# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidBuitenweg/DataScience-Demo-2025/blob/main/DataScience_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ingest

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Classification algorithm A

# %% [markdown]
# ### Classification algorithm B

# %% [markdown]
# ## Conclusion
